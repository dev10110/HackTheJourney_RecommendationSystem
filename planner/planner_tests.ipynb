# %%
import pandas as pd
import random
import googlemaps
from datetime import datetime

import tsp #solves the travelling salesman problem

class GoogleMapsClient():
    def __init__(self):
        
        self.gmaps = googlemaps.Client(key=os.environ['mapsAPI'])
        self.poi_latlon = None
    
    def get_place_ids_from_POIs(self,pois):
        #accept list of pois
        
        candidates = []
        
        for i in range(len(pois)):
            location_bias_string = f"point:{pois[i]['geoCode']['latitude']},{pois[i]['geoCode']['longitude']}"
            candidate = self.gmaps.find_place(input = pois[i]['name'], input_type='textquery',fields=['place_id'],location_bias=location_bias_string)
            
            candidates.append(candidate['candidates'][0]['place_id']) #extracts the first poi

        return candidates
    
    def get_mean_location(self,pois):
        #uses pois returned by amadeus
        poi_latlon = [pois[i]['geoCode'] for i in range(len(pois))]
        self.poi_latlon = pd.DataFrame.from_dict(poi_latlon).mean().to_dict()
        
        return  self.poi_latlon
        

    def generate_itinerary(self, pois, hotel_lat_lon = None):
        #assume hotel is dictionary of  in the style of {'latitude': 50.085133, 'longitude': 14.424776}
        #if not provided, the hotel is assumed to be at the mean location of the pois.
        #pois are list of pois generated by amadeus
        #result is a dictionary, that has:
        #    result['path'] is the path to be taken, indexed by pois
        #    result['travel_time'] is the matrix of travel times from a poi (row) to another poi (col). Note, indexes are shifted up by 1 due to hotel being added as index 0.
        #    result['dist_matrix'] is the distances matrix returned by google.
        
        if hotel_lat_lon is None:
            hotel_lat_lon = self.get_mean_location(pois)
            
        #convert pois to lat long
        poi_latlon = self.poi_latlon = [pois[i]['geoCode'] for i in range(len(pois))]
        #saved for future reference
        
        
        #collate
        full_latlon = [hotel_lat_lon] + poi_latlon
        num_of_points = len(full_latlon)
        
        #generate distance matrix from google
        dist_matrix = self.gmaps.distance_matrix(full_latlon,full_latlon,mode='transit')
        
        #generate summary of travel times (each number is the number of seconds of travel)
        travel_time = [[dist_matrix['rows'][o]['elements'][d]['duration']['value'] for d in range(num_of_points)] for o in range(num_of_points)]
        
        
        #convert to dictionary
        r = range(len(travel_time))
        cost = {(i,j): travel_time[i][j] for i in r for j in r}
        
        #solve travelling salesman problem
        (totaltime, path) = tsp.tsp(r, cost)
        
        #correct index, because hotel was added at point 0
        poi_path = [loc-1 for loc in path[1:]]    
        
        result = dict()
        result['path'] = poi_path
        result['dist_matrix'] = dist_matrix
        result['travel_time'] = travel_time
        
        return result
                                              
    def get_details(self, place_name,location_bias=None):
        #assumes the place_name is a text to query
        if location_bias is not None:
            candidate = self.gmaps.find_place(input = place_name, input_type='textquery',fields=['place_id'], location_bias_string=location_bias)
        else:
            candidate = self.gmaps.find_place(input = place_name, input_type='textquery',fields=['place_id'])
        
        try:
            place_id = candidate['candidates'][0]['place_id'] #extracts the first poi
            details = self.gmaps.place(place_id)
            latlon = details['result']['geometry']['location']
            return {'place_id': place_id, 'latlon': latlon,'details':details}
        except:
            print('Error: Possibly, didnt find enough candidates?')
        
    def generate_itinerary_and_directions(self, pois):
        
        mean_loc = self.get_mean_location(pois)
        itin = self.generate_itinerary(pois)
        
        result = dict()
        result['mean_loc'] = mean_loc
        result['ordered_pois'] = [pois[el] for el in itin['path']]
        
        result['transits'] = []
        
        result['transits'] += [self.get_transit_directions(mean_loc, pois[itin['path'][0]])]
        
        for i in range(len(pois)-1):
            result['transits'] += [self.get_transit_directions(pois[itin['path'][i]],pois[itin['path'][i+1]])]
            
        result['transits'] += [self.get_transit_directions(pois[itin['path'][-1]], mean_loc)]
                
        return result
        
        
    def get_transit_directions(self,origin, destination, location_bias=None, mode='transit', summarise = True):
        #assume origin is either in a amadeus style or is a text entry for google maps search
        
        if location_bias is None:
            try:
                location_bias = self.poi_latlon
                
            except:
                pass
        
        if type(origin) is str:
            origin_details = self.get_details(origin, location_bias=location_bias)
            origin_latlon = origin_details['latlon']
        elif 'latitude' in origin.keys():
            origin_latlon = origin
        else:
            #assumes it is a amadeus location
            origin_latlon = origin['geoCode']
        
        if type(destination) is str:
            dest_details = self.get_details(destination, location_bias=location_bias)
            dest_latlon = dest_details['latlon']
        elif 'latitude' in destination.keys():
            dest_latlon = destination
        else:
            dest_latlon = destination['geoCode']
        
        transit = self.gmaps.directions(origin_latlon,dest_latlon,mode='transit')
        
        if summarise:
            return self.get_transit_summary(transit)
        else:
            return transit
        
        
        
    
        
        
    
    def get_transit_summary(self,transit):
        summary = dict()
        
        summary['total_time'] = transit[0]['legs'][0]['duration']['text']
        
        
        legs = dict()
        for i in range(len(transit[0]['legs'][0]['steps'])):

            dur_string  = transit[0]['legs'][0]['steps'][i]['duration']['text']
            description = transit[0]['legs'][0]['steps'][i]['html_instructions']

            legs[i] = {'duration': dur_string, 'text': description}

        summary['legs'] = legs

        
        return summary

# %%
for i in range(1):
    print(2)
# Out:
# 2

# %%
legs=dict()

# %%
legs[0] = {'duration': '4 mins', 'text': 'walk'}

# %%
legs
# Out:
# {0: {'duration': '4 mins', 'text': 'walk'}}

# %%
import os
os.chdir('../data-import/')

from AmadeusClient import AmadeusClient

am = AmadeusClient()

os.chdir('../planner/')

# %%
# Out:
# True

# %%
am

# %%
pois = random.sample(pois, k = 9)
pois
# Out:
# [{'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.092182, 'longitude': 14.449174},
#   'name': 'Charleston',
#   'category': 'RESTAURANT',
#   'tags': ['restaurant'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.085323, 'longitude': 14.42018},
#   'name': 'AnonymouS Bar',
#   'category': 'RESTAURANT',
#   'tags': ['restaurant', 'bar', 'club', 'nightlife'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.082363, 'longitude': 14.423106},
#   'name': 'Franciscan garden Františkánská zahrada',
#   'category': 'SIGHTS',
#   'tags': ['garden'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.08469, 'longitude': 14.423233},
#   'name': 'U Provaznice',
#   'category': 'RESTAURANT',
#   'tags': ['restaurant'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.089954, 'longitude': 14.415439},
#   'name': 'Rudolfinum',
#   'category': 'SIGHTS',
#   'tags': ['sightseeing', 'restaurant', 'artgallerie', 'sights', 'landmark'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.086975, 'longitude': 14.425542},
#   'name': 'Grand Café Orient',
#   'category': 'RESTAURANT',
#   'tags': ['sightseeing', 'restaurant', 'bar', 'nightlife'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.089893, 'longitude': 14.416262},
#   'name': 'Museum of Decorative Arts in Prague',
#   'category': 'SIGHTS',
#   'tags': ['sightseeing', 'museum', 'sights'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.089558, 'longitude': 14.421881},
#   'name': "Tretter's",
#   'category': 'RESTAURANT',
#   'tags': ['restaurant', 'bar', 'nightlife'],
#   'city': ''},
#  {'type': 'location',
#   'subType': 'POINT_OF_INTEREST',
#   'geoCode': {'latitude': 50.098404, 'longitude': 14.427036},
#   'name': 'Peperoncino',
#   'category': 'RESTAURANT',
#   'tags': ['sightseeing', 'restaurant'],
#   'city': ''}]

# %%
client = GoogleMapsClient()

# %%
placeids = client.get_place_ids_from_POIs(pois)

# %%
itin = client.generate_itinerary(pois)

# %%
itin.keys()
# Out:
# dict_keys(['path', 'dist_matrix', 'travel_time'])

# %%
type(itin['path'][0])
# Out:
# numpy.int64

# %%
pois[0, 2, 1, 3, 5, 8, 6, 4, 7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-409-2b1b9822ad21> in <module>
# ----> 1 pois([0, 2, 1, 3, 5, 8, 6, 4, 7])
#
# TypeError: 'list' object is not callable

# %%
client.get_mean_location(pois)
# Out:
# {'latitude': 50.08881577777778, 'longitude': 14.424650333333334}

# %%
len(client.get_transit_directions(client.get_mean_location(pois),pois[path[0]], summarise=False)[0]['legs'])
# Out:
# 1

# %%
client.generate_itinerary_and_directions(pois)
# Out:
# {'mean_loc': {'latitude': 50.08881577777778, 'longitude': 14.424650333333334},
#  'ordered_pois': [{'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.089558, 'longitude': 14.421881},
#    'name': "Tretter's",
#    'category': 'RESTAURANT',
#    'tags': ['restaurant', 'bar', 'nightlife'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.089893, 'longitude': 14.416262},
#    'name': 'Museum of Decorative Arts in Prague',
#    'category': 'SIGHTS',
#    'tags': ['sightseeing', 'museum', 'sights'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.089954, 'longitude': 14.415439},
#    'name': 'Rudolfinum',
#    'category': 'SIGHTS',
#    'tags': ['sightseeing', 'restaurant', 'artgallerie', 'sights', 'landmark'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.085323, 'longitude': 14.42018},
#    'name': 'AnonymouS Bar',
#    'category': 'RESTAURANT',
#    'tags': ['restaurant', 'bar', 'club', 'nightlife'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.082363, 'longitude': 14.423106},
#    'name': 'Franciscan garden Františkánská zahrada',
#    'category': 'SIGHTS',
#    'tags': ['garden'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.08469, 'longitude': 14.423233},
#    'name': 'U Provaznice',
#    'category': 'RESTAURANT',
#    'tags': ['restaurant'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.092182, 'longitude': 14.449174},
#    'name': 'Charleston',
#    'category': 'RESTAURANT',
#    'tags': ['restaurant'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.098404, 'longitude': 14.427036},
#    'name': 'Peperoncino',
#    'category': 'RESTAURANT',
#    'tags': ['sightseeing', 'restaurant'],
#    'city': ''},
#   {'type': 'location',
#    'subType': 'POINT_OF_INTEREST',
#    'geoCode': {'latitude': 50.086975, 'longitude': 14.425542},
#    'name': 'Grand Café Orient',
#    'category': 'RESTAURANT',
#    'tags': ['sightseeing', 'restaurant', 'bar', 'nightlife'],
#    'city': ''}],
#  'transits': [{'total_time': '3 mins',
#    'legs': {0: {'duration': '3 mins',
#      'text': 'Walk to V Kolkovně 921/3, 110 00 Praha-Staré Město, Czechia'}}},
#   {'total_time': '7 mins',
#    'legs': {0: {'duration': '7 mins',
#      'text': 'Walk to 17. listopadu 2, 110 00 Praha 1-Staré Město, Czechia'}}},
#   {'total_time': '2 mins',
#    'legs': {0: {'duration': '2 mins',
#      'text': 'Walk to Alšovo nábř. 12, 110 00 Praha 1-Staré Město, Czechia'}}},
#   {'total_time': '12 mins',
#    'legs': {0: {'duration': '12 mins',
#      'text': 'Walk to Michalská 433/14, 110 00 Praha-Staré Město, Czechia'}}},
#   {'total_time': '5 mins',
#    'legs': {0: {'duration': '5 mins',
#      'text': 'Walk to Jungmannova 748/30, Nové Město, 110 00 Praha-Praha 1, Czechia'}}},
#   {'total_time': '4 mins',
#    'legs': {0: {'duration': '4 mins',
#      'text': 'Walk to Provaznická 388/2, 110 00 Praha-Staré Město, Czechia'}}},
#   {'total_time': '12 mins',
#    'legs': {0: {'duration': '2 mins', 'text': 'Walk to Můstek'},
#     1: {'duration': '4 mins', 'text': 'Subway towards Černý Most'},
#     2: {'duration': '6 mins',
#      'text': 'Walk to Křižíkova 208/55, 186 00 Karlín, Czechia'}}},
#   {'total_time': '22 mins',
#    'legs': {0: {'duration': '5 mins', 'text': 'Walk to Karlínské náměstí'},
#     1: {'duration': '8 mins', 'text': 'Tram towards Vozovna Kobylisy'},
#     2: {'duration': '9 mins',
#      'text': 'Walk to Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia'}}},
#   {'total_time': '15 mins',
#    'legs': {0: {'duration': '4 mins', 'text': 'Walk to Kamenická'},
#     1: {'duration': '5 mins', 'text': 'Tram towards Spořilov'},
#     2: {'duration': '6 mins',
#      'text': 'Walk to Ovocný trh 19, 110 00 Praha 1-Staré Město, Czechia'}}},
#   {'total_time': '4 mins',
#    'legs': {0: {'duration': '4 mins',
#      'text': 'Walk to Malá Štupartská 977/8, 110 00 Praha-Staré Město, Czechia'}}}]}

# %%
self.get_transit_summary

# %%
gmaps.find_place('BER',input_type='textquery')
# Out:
# {'candidates': [{'place_id': 'ChIJq_-Z1yoFdkgRpXtYsZTGvGk'}], 'status': 'OK'}

# %%
gmaps.place('ChIJq_-Z1yoFdkgRpXtYsZTGvGk')['result']
# Out:
# {'address_components': [{'long_name': '20',
#    'short_name': '20',
#    'types': ['street_number']},
#   {'long_name': 'Cannon Street',
#    'short_name': 'Cannon St',
#    'types': ['route']},
#   {'long_name': 'London', 'short_name': 'London', 'types': ['postal_town']},
#   {'long_name': 'Greater London',
#    'short_name': 'Greater London',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'England',
#    'short_name': 'England',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United Kingdom',
#    'short_name': 'GB',
#    'types': ['country', 'political']},
#   {'long_name': 'EC4M 6XD',
#    'short_name': 'EC4M 6XD',
#    'types': ['postal_code']}],
#  'adr_address': '<span class="street-address">20 Cannon St</span>, <span class="locality">London</span> <span class="postal-code">EC4M 6XD</span>, <span class="country-name">UK</span>',
#  'formatted_address': '20 Cannon St, London EC4M 6XD, UK',
#  'formatted_phone_number': '020 7529 1111',
#  'geometry': {'location': {'lat': 51.51241109999999,
#    'lng': -0.09544369999999999},
#   'viewport': {'northeast': {'lat': 51.5139070302915,
#     'lng': -0.09401981970849799},
#    'southwest': {'lat': 51.5112090697085, 'lng': -0.09671778029150205}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#  'id': '23b0d3d2edb22bea05df6fe5daec0c1af4085d93',
#  'international_phone_number': '+44 20 7529 1111',
#  'name': 'Odgers Berndtson',
#  'opening_hours': {'open_now': False,
#   'periods': [{'close': {'day': 1, 'time': '1730'},
#     'open': {'day': 1, 'time': '0900'}},
#    {'close': {'day': 2, 'time': '1730'}, 'open': {'day': 2, 'time': '0900'}},
#    {'close': {'day': 3, 'time': '1730'}, 'open': {'day': 3, 'time': '0900'}},
#    {'close': {'day': 4, 'time': '1730'}, 'open': {'day': 4, 'time': '0900'}},
#    {'close': {'day': 5, 'time': '1730'}, 'open': {'day': 5, 'time': '0900'}}],
#   'weekday_text': ['Monday: 9:00 AM – 5:30 PM',
#    'Tuesday: 9:00 AM – 5:30 PM',
#    'Wednesday: 9:00 AM – 5:30 PM',
#    'Thursday: 9:00 AM – 5:30 PM',
#    'Friday: 9:00 AM – 5:30 PM',
#    'Saturday: Closed',
#    'Sunday: Closed']},
#  'photos': [{'height': 1152,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106077197312538525005/photos">Odgers Berndtson</a>'],
#    'photo_reference': 'CmRaAAAAwZ9CibqPjSf_7JPL2YBnt5mV_j0z3xXNmMgY4_hnwhSfGvkSqDOdPVeyXXQMi18XNpS1gFWJ8lo2fJbFVYKT0m1rWynPXpM3OJOtz2jthbZ9Q7_r3K2gPtq8GbAw3Co5EhAwtpoAhISw63eWQ_2FI7yyGhTrz4obPsK6Sa2skCba0r6X6MuQFw',
#    'width': 2048},
#   {'height': 2592,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116389284916561537674/photos">Ali E</a>'],
#    'photo_reference': 'CmRaAAAA3TU4uCFtls_4tGygpHPqLJ-Ru8Si7Uwli-mvPvz3P7Aaeh6O4IqQ5vixlhwiTJeWSsadoa815CI3-ic8V3P1WgY1pkFp9m7S5BssdJH6SGu-q08Tx6qQwv5f-aJYCvQeEhDNrucdaXr0FybX0HCCQZmbGhShVQHK6JXlVo7SvbcpA5HuhVcgug',
#    'width': 4608},
#   {'height': 3264,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106114045831083059125/photos">rex mentor</a>'],
#    'photo_reference': 'CmRaAAAAMWFMVJ_molJ5SsTPPWIY0Pqq_RY_11CVMgfuZuZ62z0QKUm9_-h4bNhLRItWeG9R4gdyHvTp7U9mD4SGjqwBjwzKesF0YDa2-aDPOlnAeM0R5Y2K0s2SYUESE2SJxKaQEhDeKz8PQnAC1F-aHc0cqg8sGhQNmIyYyiuuiovDrXNxrYIi-N6n2w',
#    'width': 2448},
#   {'height': 1080,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114729493616527998727/photos">Toby Powell-Blyth</a>'],
#    'photo_reference': 'CmRaAAAAIyTkGzOWsLGgP8ASagAZOqln_5hOZ2MgVZqVvV9myjWfUZcOylQtPdvmXQK53uxdQ2kL78Jik6E3LFS6V2RlaxsWp-dszXAWAn_Nc4e9d2EDxHQyF_NFWhALK6mP11W3EhBeOfnntDWgZYhXJ70hi01OGhQjKxGtFPYnafjBs5DmE6gEyFN55g',
#    'width': 1920},
#   {'height': 2448,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106114045831083059125/photos">rex mentor</a>'],
#    'photo_reference': 'CmRaAAAAjvaEQXnDhbKTLx4RbNoz-UAEKXgdnFnU2NQ18QZnqqqZH5ocHOVZhptIexEKenytdft5uEX5jkRSKwHnxpYX0OYMJhxzWed7Q0dDN_teU4seSnl3YrHtHl7xtmDINM1lEhBkzoEMCiaHuogmg0WanfGeGhSd80CEszgdNaK1gEOpK0CPxUTUDA',
#    'width': 3264},
#   {'height': 1000,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106077197312538525005/photos">Odgers Berndtson</a>'],
#    'photo_reference': 'CmRaAAAAFE-9Q_Ly3QEakxQ5NC_3-Qc5xq8ZIsTAEb6uMOlp9VuXZuWMygcCswjRGPsnLWXEn0qii_aACSE7wjNCkikB64MtiBBPjY4N60ELomnzHvTjJv6s_biWR415waifvzrWEhCEtAaNfG0elJlZqCBkYu2QGhTodBKR8HHhtYWDanZNeNZotvS62g',
#    'width': 1000}],
#  'place_id': 'ChIJq_-Z1yoFdkgRpXtYsZTGvGk',
#  'plus_code': {'compound_code': 'GW63+XR London, United Kingdom',
#   'global_code': '9C3XGW63+XR'},
#  'rating': 4.5,
#  'reference': 'ChIJq_-Z1yoFdkgRpXtYsZTGvGk',
#  'reviews': [{'author_name': 'rex mentor',
#    'author_url': 'https://www.google.com/maps/contrib/106114045831083059125/reviews',
#    'language': 'en',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/-yLM6Mm1P0iI/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3retYFeWkgQ9hDlqH6S12oVhejtBbA/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg',
#    'rating': 4,
#    'relative_time_description': '3 weeks ago',
#    'text': 'Odgers Berndston is an ideal place for interviews and meetings.',
#    'time': 1562100443},
#   {'author_name': 'Albino Zoo',
#    'author_url': 'https://www.google.com/maps/contrib/100396345408874133160/reviews',
#    'language': 'en',
#    'profile_photo_url': 'https://lh6.googleusercontent.com/-0aFGo0Xa0e8/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3reSiunHbefoIkFMFOxhDPL-j7viUA/s128-c0x00000000-cc-rp-mo/photo.jpg',
#    'rating': 1,
#    'relative_time_description': '4 months ago',
#    'text': "Rude and unprofessional. Consultant turned up late for a video interview, leaving a clueless (presumably recent graduate) to conduct proceedings. Didn't bother to get back to me. Rest assured if this is my experience as a candidate, I will not be using them when I am next recruiting",
#    'time': 1553169944},
#   {'author_name': 'Cristina Raiu',
#    'author_url': 'https://www.google.com/maps/contrib/107217089614315475391/reviews',
#    'language': 'en',
#    'profile_photo_url': 'https://lh6.googleusercontent.com/-E7oScAXcUE0/AAAAAAAAAAI/AAAAAAAAbTQ/caCsdfPn7yE/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg',
#    'rating': 5,
#    'relative_time_description': 'a year ago',
#    'text': 'Good',
#    'time': 1526226655},
#   {'author_name': 'Hyt R',
#    'author_url': 'https://www.google.com/maps/contrib/114115374331518978604/reviews',
#    'language': 'en',
#    'profile_photo_url': 'https://lh5.googleusercontent.com/-00hEiufPm4k/AAAAAAAAAAI/AAAAAAAAplQ/PlfZfN354dQ/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg',
#    'rating': 5,
#    'relative_time_description': '2 years ago',
#    'text': 'Excellent place to work, ',
#    'time': 1493665999},
#   {'author_name': 'Lynette Denny',
#    'author_url': 'https://www.google.com/maps/contrib/101695055851001846504/reviews',
#    'profile_photo_url': 'https://lh3.googleusercontent.com/-KHOlsSrAvyA/AAAAAAAAAAI/AAAAAAAAA7M/4nyzZjtWvqU/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg',
#    'rating': 5,
#    'relative_time_description': 'a month ago',
#    'text': '',
#    'time': 1560705975}],
#  'scope': 'GOOGLE',
#  'types': ['point_of_interest', 'establishment'],
#  'url': 'https://maps.google.com/?cid=7619183011536862117',
#  'user_ratings_total': 16,
#  'utc_offset': 60,
#  'vicinity': '20 Cannon Street, London',
#  'website': 'https://www.odgersberndtson.com/en-gb/locations/united-kingdom?utm_source=gmb&utm_medium=organic&utm_campaign=london'}

# %%
client.get_details(['ChIJq_-Z1yoFdkgRpXtYsZTGvGk'])
# Out:
# Possibly, didnt find enough candidates?

# %%
hotel=client.get_mean_location(pois)

# %%
len(pois[:-1])
# Out:
# 9

# %%
itinerary = client.generate_itinerary(pois = pois[:-1], hotel_lat_lon= hotel)

# %%
itinerary
# Out:
# {'path': [4, 0, 2, 1, 7, 3, 5, 6, 8],
#  'dist_matrix': {'destination_addresses': ['Týnská 21, 110 00 Staré Město, Czechia',
#    'Křižíkova 208/55, 186 00 Karlín, Czechia',
#    'Provaznická 388/2, 110 00 Praha-Staré Město, Czechia',
#    'Ovocný trh 19, 110 00 Praha 1-Staré Město, Czechia',
#    'Valentinská 56/11, 110 00 Praha-Staré Město, Czechia',
#    'Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia',
#    'Alšovo nábř. 12, 110 00 Praha 1-Staré Město, Czechia',
#    '17. listopadu 2, 110 00 Praha 1-Staré Město, Czechia',
#    'Michalská 433/14, 110 00 Praha-Staré Město, Czechia',
#    'V Kolkovně 921/3, 110 00 Praha-Staré Město, Czechia'],
#   'origin_addresses': ['Týnská 21, 110 00 Staré Město, Czechia',
#    'Křižíkova 208/55, 186 00 Karlín, Czechia',
#    'Provaznická 388/2, 110 00 Praha-Staré Město, Czechia',
#    'Ovocný trh 19, 110 00 Praha 1-Staré Město, Czechia',
#    'Valentinská 56/11, 110 00 Praha-Staré Město, Czechia',
#    'Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia',
#    'Alšovo nábř. 12, 110 00 Praha 1-Staré Město, Czechia',
#    '17. listopadu 2, 110 00 Praha 1-Staré Město, Czechia',
#    'Michalská 433/14, 110 00 Praha-Staré Město, Czechia',
#    'V Kolkovně 921/3, 110 00 Praha-Staré Město, Czechia'],
#   'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '2.1 km', 'value': 2071},
#       'duration': {'text': '26 mins', 'value': 1531},
#       'status': 'OK'},
#      {'distance': {'text': '0.7 km', 'value': 655},
#       'duration': {'text': '8 mins', 'value': 485},
#       'status': 'OK'},
#      {'distance': {'text': '0.4 km', 'value': 368},
#       'duration': {'text': '5 mins', 'value': 276},
#       'status': 'OK'},
#      {'distance': {'text': '0.7 km', 'value': 658},
#       'duration': {'text': '8 mins', 'value': 481},
#       'status': 'OK'},
#      {'distance': {'text': '2.3 km', 'value': 2337},
#       'duration': {'text': '13 mins', 'value': 804},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.9 km', 'value': 891},
#       'duration': {'text': '11 mins', 'value': 660},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 800},
#       'duration': {'text': '10 mins', 'value': 585},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 580},
#       'duration': {'text': '7 mins', 'value': 426},
#       'status': 'OK'},
#      {'distance': {'text': '0.3 km', 'value': 251},
#       'duration': {'text': '3 mins', 'value': 179},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '2.5 km', 'value': 2480},
#       'duration': {'text': '18 mins', 'value': 1087},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '3.0 km', 'value': 2967},
#       'duration': {'text': '18 mins', 'value': 1091},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '2.2 km', 'value': 2200},
#       'duration': {'text': '18 mins', 'value': 1063},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '3.0 km', 'value': 3024},
#       'duration': {'text': '25 mins', 'value': 1491},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '3.9 km', 'value': 3913},
#       'duration': {'text': '28 mins', 'value': 1661},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '3.2 km', 'value': 3152},
#       'duration': {'text': '27 mins', 'value': 1591},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '3.1 km', 'value': 3062},
#       'duration': {'text': '25 mins', 'value': 1516},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '3.2 km', 'value': 3176},
#       'duration': {'text': '21 mins', 'value': 1254},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '2.5 km', 'value': 2512},
#       'duration': {'text': '19 mins', 'value': 1110},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.7 km', 'value': 655},
#       'duration': {'text': '8 mins', 'value': 460},
#       'status': 'OK'},
#      {'distance': {'text': '2.9 km', 'value': 2879},
#       'duration': {'text': '18 mins', 'value': 1103},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '0.4 km', 'value': 361},
#       'duration': {'text': '4 mins', 'value': 256},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 842},
#       'duration': {'text': '10 mins', 'value': 605},
#       'status': 'OK'},
#      {'distance': {'text': '3.9 km', 'value': 3899},
#       'duration': {'text': '20 mins', 'value': 1224},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1.1 km', 'value': 1097},
#       'duration': {'text': '13 mins', 'value': 800},
#       'status': 'OK'},
#      {'distance': {'text': '1.0 km', 'value': 1016},
#       'duration': {'text': '12 mins', 'value': 729},
#       'status': 'OK'},
#      {'distance': {'text': '0.4 km', 'value': 357},
#       'duration': {'text': '4 mins', 'value': 253},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 794},
#       'duration': {'text': '9 mins', 'value': 564},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.4 km', 'value': 368},
#       'duration': {'text': '4 mins', 'value': 267},
#       'status': 'OK'},
#      {'distance': {'text': '1.9 km', 'value': 1889},
#       'duration': {'text': '23 mins', 'value': 1387},
#       'status': 'OK'},
#      {'distance': {'text': '0.4 km', 'value': 361},
#       'duration': {'text': '4 mins', 'value': 268},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 797},
#       'duration': {'text': '10 mins', 'value': 575},
#       'status': 'OK'},
#      {'distance': {'text': '2.4 km', 'value': 2384},
#       'duration': {'text': '14 mins', 'value': 831},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1.1 km', 'value': 1052},
#       'duration': {'text': '13 mins', 'value': 770},
#       'status': 'OK'},
#      {'distance': {'text': '1.0 km', 'value': 970},
#       'duration': {'text': '12 mins', 'value': 699},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 588},
#       'duration': {'text': '7 mins', 'value': 428},
#       'status': 'OK'},
#      {'distance': {'text': '0.5 km', 'value': 546},
#       'duration': {'text': '7 mins', 'value': 394},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.7 km', 'value': 658},
#       'duration': {'text': '8 mins', 'value': 482},
#       'status': 'OK'},
#      {'distance': {'text': '3.7 km', 'value': 3656},
#       'duration': {'text': '28 mins', 'value': 1683},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 842},
#       'duration': {'text': '10 mins', 'value': 628},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 797},
#       'duration': {'text': '10 mins', 'value': 586},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '2.9 km', 'value': 2881},
#       'duration': {'text': '20 mins', 'value': 1211},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.3 km', 'value': 296},
#       'duration': {'text': '4 mins', 'value': 227},
#       'status': 'OK'},
#      {'distance': {'text': '0.2 km', 'value': 226},
#       'duration': {'text': '3 mins', 'value': 168},
#       'status': 'OK'},
#      {'distance': {'text': '0.7 km', 'value': 676},
#       'duration': {'text': '8 mins', 'value': 499},
#       'status': 'OK'},
#      {'distance': {'text': '0.5 km', 'value': 512},
#       'duration': {'text': '6 mins', 'value': 376},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '2.3 km', 'value': 2341},
#       'duration': {'text': '14 mins', 'value': 849},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '4.1 km', 'value': 4051},
#       'duration': {'text': '27 mins', 'value': 1629},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '4.0 km', 'value': 4006},
#       'duration': {'text': '21 mins', 'value': 1287},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '2.7 km', 'value': 2739},
#       'duration': {'text': '15 mins', 'value': 913},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '2.8 km', 'value': 2844},
#       'duration': {'text': '20 mins', 'value': 1222},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '1.6 km', 'value': 1594},
#       'duration': {'text': '20 mins', 'value': 1178},
#       'status': 'OK'},
#      {'distance': {'text': '1.6 km', 'value': 1580},
#       'duration': {'text': '20 mins', 'value': 1179},
#       'status': 'OK'},
#      {'distance': {'text': '4.2 km', 'value': 4215},
#       'duration': {'text': '24 mins', 'value': 1450},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '2.3 km', 'value': 2332},
#       'duration': {'text': '14 mins', 'value': 841},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.9 km', 'value': 891},
#       'duration': {'text': '11 mins', 'value': 661},
#       'status': 'OK'},
#      {'distance': {'text': '3.9 km', 'value': 3911},
#       'duration': {'text': '31 mins', 'value': 1875},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1.1 km', 'value': 1097},
#       'duration': {'text': '14 mins', 'value': 820},
#       'status': 'OK'},
#      {'distance': {'text': '1.1 km', 'value': 1052},
#       'duration': {'text': '13 mins', 'value': 778},
#       'status': 'OK'},
#      {'distance': {'text': '0.3 km', 'value': 296},
#       'duration': {'text': '4 mins', 'value': 224},
#       'status': 'OK'},
#      {'distance': {'text': '1.6 km', 'value': 1599},
#       'duration': {'text': '22 mins', 'value': 1319},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '0.2 km', 'value': 182},
#       'duration': {'text': '2 mins', 'value': 142},
#       'status': 'OK'},
#      {'distance': {'text': '0.9 km', 'value': 931},
#       'duration': {'text': '12 mins', 'value': 691},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 640},
#       'duration': {'text': '8 mins', 'value': 472},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.8 km', 'value': 800},
#       'duration': {'text': '10 mins', 'value': 585},
#       'status': 'OK'},
#      {'distance': {'text': '3.1 km', 'value': 3065},
#       'duration': {'text': '27 mins', 'value': 1628},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '1.0 km', 'value': 1016},
#       'duration': {'text': '12 mins', 'value': 748},
#       'status': 'OK'},
#      {'distance': {'text': '1.0 km', 'value': 970},
#       'duration': {'text': '12 mins', 'value': 707},
#       'status': 'OK'},
#      {'distance': {'text': '0.2 km', 'value': 226},
#       'duration': {'text': '3 mins', 'value': 164},
#       'status': 'OK'},
#      {'distance': {'text': '2.9 km', 'value': 2919},
#       'duration': {'text': '21 mins', 'value': 1232},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.2 km', 'value': 182},
#       'duration': {'text': '2 mins', 'value': 139},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 849},
#       'duration': {'text': '10 mins', 'value': 620},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 550},
#       'duration': {'text': '7 mins', 'value': 397},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.6 km', 'value': 580},
#       'duration': {'text': '7 mins', 'value': 418},
#       'status': 'OK'},
#      {'distance': {'text': '3.2 km', 'value': 3171},
#       'duration': {'text': '21 mins', 'value': 1278},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.4 km', 'value': 357},
#       'duration': {'text': '4 mins', 'value': 265},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 588},
#       'duration': {'text': '7 mins', 'value': 428},
#       'status': 'OK'},
#      {'distance': {'text': '0.7 km', 'value': 676},
#       'duration': {'text': '8 mins', 'value': 490},
#       'status': 'OK'},
#      {'distance': {'text': '4.2 km', 'value': 4191},
#       'duration': {'text': '23 mins', 'value': 1399},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.9 km', 'value': 931},
#       'duration': {'text': '11 mins', 'value': 685},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 849},
#       'duration': {'text': '10 mins', 'value': 614},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 645},
#       'duration': {'text': '8 mins', 'value': 466},
#       'status': 'OK'}]},
#    {'elements': [{'distance': {'text': '0.3 km', 'value': 251},
#       'duration': {'text': '3 mins', 'value': 189},
#       'status': 'OK'},
#      {'distance': {'text': '2.8 km', 'value': 2842},
#       'duration': {'text': '27 mins', 'value': 1612},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.8 km', 'value': 794},
#       'duration': {'text': '10 mins', 'value': 593},
#       'status': 'OK'},
#      {'distance': {'text': '0.5 km', 'value': 546},
#       'duration': {'text': '7 mins', 'value': 413},
#       'status': 'OK'},
#      {'distance': {'text': '0.5 km', 'value': 512},
#       'duration': {'text': '6 mins', 'value': 381},
#       'status': 'OK'},
#      {'distance': {'text': '2.4 km', 'value': 2369},
#       'duration': {'text': '14 mins', 'value': 835},
#       'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 640},
#       'duration': {'text': '8 mins', 'value': 481},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 550},
#       'duration': {'text': '7 mins', 'value': 406},
#       'status': 'OK'},
#      {'distance': {'text': '0.6 km', 'value': 645},
#       'duration': {'text': '8 mins', 'value': 480},
#       'status': 'OK'},
#      {'distance': {'text': '1 m', 'value': 0},
#       'duration': {'text': '1 min', 'value': 0},
#       'status': 'OK'}]}],
#   'status': 'OK'},
#  'travel_time': [[0, 1531, 485, 276, 481, 804, 660, 585, 426, 179],
#   [1087, 0, 1091, 1063, 1491, 1661, 1591, 1516, 1254, 1110],
#   [460, 1103, 0, 256, 605, 1224, 800, 729, 253, 564],
#   [267, 1387, 268, 0, 575, 831, 770, 699, 428, 394],
#   [482, 1683, 628, 586, 0, 1211, 227, 168, 499, 376],
#   [849, 1629, 1287, 913, 1222, 0, 1178, 1179, 1450, 841],
#   [661, 1875, 820, 778, 224, 1319, 0, 142, 691, 472],
#   [585, 1628, 748, 707, 164, 1232, 139, 0, 620, 397],
#   [418, 1278, 265, 428, 490, 1399, 685, 614, 0, 466],
#   [189, 1612, 593, 413, 381, 835, 481, 406, 480, 0]]}

# %%
path = itinerary['path']

# %%
path
# Out:
# [4, 0, 2, 1, 7, 3, 5, 6, 8]

# %%
hotel
# Out:
# {'latitude': 50.0887656, 'longitude': 14.423813200000001}

# %%
pois[path[0]].keys()
# Out:
# dict_keys(['type', 'subType', 'geoCode', 'name', 'category', 'tags', 'city'])

# %%
transit_dir = client.get_transit_directions(hotel, pois[path[0]])

# %%
transit_dir
# Out:
# {'total_time': '13 mins',
#  'legs': {0: {'duration': '5 mins', 'text': 'Walk to Dlouhá třída'},
#   1: {'duration': '5 mins', 'text': 'Tram towards Divoká Šárka'},
#   2: {'duration': '4 mins',
#    'text': 'Walk to Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia'}}}

# %%
for i in range(len(transit_dir[0]['legs'][0]['steps'])):
    dur_string = transit_dir[0]['legs'][0]['steps'][i]['duration']['text']
    description = transit_dir[0]['legs'][0]['steps'][i]['html_instructions']
    
    print(dur_string,': ', description)

print('Total time: ', transit_dir[0]['legs'][0]['duration']['text'])
# Out:
# 5 mins :  Walk to Dlouhá třída
# 5 mins :  Tram towards Divoká Šárka
# 4 mins :  Walk to Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia
# Total time:  14 mins

# %%
transit_dir
# Out:
# [{'bounds': {'northeast': {'lat': 50.09986319999999, 'lng': 14.4332601},
#    'southwest': {'lat': 50.08877649999999, 'lng': 14.4238037}},
#   'copyrights': 'Map data ©2019 Google',
#   'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#   'legs': [{'arrival_time': {'text': '3:03am',
#      'time_zone': 'Europe/Prague',
#      'value': 1564362238},
#     'departure_time': {'text': '2:49am',
#      'time_zone': 'Europe/Prague',
#      'value': 1564361374},
#     'distance': {'text': '2.3 km', 'value': 2336},
#     'duration': {'text': '14 mins', 'value': 864},
#     'end_address': 'Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia',
#     'end_location': {'lat': 50.0983823, 'lng': 14.4270437},
#     'start_address': 'Týnská 21, 110 00 Staré Město, Czechia',
#     'start_location': {'lat': 50.08877649999999, 'lng': 14.4238037},
#     'steps': [{'distance': {'text': '0.4 km', 'value': 440},
#       'duration': {'text': '5 mins', 'value': 325},
#       'end_location': {'lat': 50.0905274, 'lng': 14.4278384},
#       'html_instructions': 'Walk to Dlouhá třída',
#       'polyline': {'points': '{}upHwc`wA[mAIOCDCBk@`@WkAI_@SaAYsAGe@@SA]ASAIHEDACUM{@_@uBSgAIIAo@Ac@?GAU[Dw@LM@'},
#       'start_location': {'lat': 50.08877649999999, 'lng': 14.4238037},
#       'steps': [{'distance': {'text': '36 m', 'value': 36},
#         'duration': {'text': '1 min', 'value': 25},
#         'end_location': {'lat': 50.08897, 'lng': 14.4242678},
#         'html_instructions': 'Head <b>northeast</b> on <b>Týnská</b> toward <b>Malá Štupartská</b>',
#         'polyline': {'points': '{}upHwc`wA[mAIO'},
#         'start_location': {'lat': 50.08877649999999, 'lng': 14.4238037},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '44 m', 'value': 44},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 50.089235, 'lng': 14.4240526},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malá Štupartská</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'a_vpHuf`wACDCBk@`@'},
#         'start_location': {'lat': 50.08897, 'lng': 14.4242678},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 153},
#         'duration': {'text': '2 mins', 'value': 112},
#         'end_location': {'lat': 50.0896887, 'lng': 14.4259292},
#         'html_instructions': 'Turn <b>right</b> onto <b>Masná</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'u`vpHie`wAWkAI_@SaAYsAGe@@SA]ASAI'},
#         'start_location': {'lat': 50.089235, 'lng': 14.4240526},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '10 m', 'value': 10},
#         'duration': {'text': '1 min', 'value': 7},
#         'end_location': {'lat': 50.08962709999999, 'lng': 14.4260829},
#         'html_instructions': 'Turn <b>right</b> onto <b>Rybná</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'qcvpHaq`wAHEDACU'},
#         'start_location': {'lat': 50.0896887, 'lng': 14.4259292},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 142},
#         'duration': {'text': '2 mins', 'value': 108},
#         'end_location': {'lat': 50.0900365, 'lng': 14.4279542},
#         'html_instructions': 'Turn <b>left</b> onto <b>Benediktská</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'ecvpH_r`wAM{@_@uBSgAIIAo@Ac@?GAU'},
#         'start_location': {'lat': 50.08962709999999, 'lng': 14.4260829},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 50.0905274, 'lng': 14.4278384},
#         'html_instructions': 'Turn <b>left</b> onto <b>Revoluční</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'wevpHu}`wA[Dw@LM@'},
#         'start_location': {'lat': 50.0900365, 'lng': 14.4279542},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '1.6 km', 'value': 1587},
#       'duration': {'text': '5 mins', 'value': 300},
#       'end_location': {'lat': 50.09970999999999, 'lng': 14.42857},
#       'html_instructions': 'Tram towards Divoká Šárka',
#       'polyline': {'points': '{hvpHk}`wAg@FwB^aG`AqALo@Na@FkDf@qAPwAVWBYDw@wH[qDMwBSwBWu@SeA[_BOk@]w@So@Ui@a@i@][c@_@sAaAQAeDBm@@u@fGk@zG{@dKIC'},
#       'start_location': {'lat': 50.09054, 'lng': 14.4279},
#       'transit_details': {'arrival_stop': {'location': {'lat': 50.09970999999999,
#          'lng': 14.42857},
#         'name': 'Kamenická'},
#        'arrival_time': {'text': '3:00am',
#         'time_zone': 'Europe/Prague',
#         'value': 1564362000},
#        'departure_stop': {'location': {'lat': 50.09054, 'lng': 14.4279},
#         'name': 'Dlouhá třída'},
#        'departure_time': {'text': '2:55am',
#         'time_zone': 'Europe/Prague',
#         'value': 1564361700},
#        'headsign': 'Divoká Šárka',
#        'line': {'agencies': [{'name': 'Pražská integrovaná doprava',
#           'phone': '011 420 234 704 560',
#           'url': 'https://pid.cz/'}],
#         'color': '#8b0202',
#         'name': 'Divoká Šárka - Nádraží Strašnice',
#         'short_name': '91',
#         'text_color': '#ffffff',
#         'url': 'https://pid.cz/linka/91',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/tram2.png',
#          'name': 'Tram',
#          'type': 'TRAM'}},
#        'num_stops': 2},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.3 km', 'value': 309},
#       'duration': {'text': '4 mins', 'value': 238},
#       'end_location': {'lat': 50.0983823, 'lng': 14.4270437},
#       'html_instructions': 'Walk to Letohradská 648/34, 170 00 Praha 7-Holešovice, Czechia',
#       'polyline': {'points': 'abxpHoaawACVCVYhDNGbA_@tDmABTXtD'},
#       'start_location': {'lat': 50.0996921, 'lng': 14.4285646},
#       'steps': [{'distance': {'text': '83 m', 'value': 83},
#         'duration': {'text': '1 min', 'value': 65},
#         'end_location': {'lat': 50.0997833, 'lng': 14.4275058},
#         'html_instructions': 'Head <b>west</b> on <b>M. Horákové</b> toward <b>Haškova</b>',
#         'polyline': {'points': 'abxpHoaawACVCVYhDNG'},
#         'start_location': {'lat': 50.0996921, 'lng': 14.4285646},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 156},
#         'duration': {'text': '2 mins', 'value': 112},
#         'end_location': {'lat': 50.0985148, 'lng': 14.427954},
#         'html_instructions': 'Turn <b>left</b> onto <b>Kamenická</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'sbxpH}z`wAbA_@tDmABT'},
#         'start_location': {'lat': 50.0997833, 'lng': 14.4275058},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '70 m', 'value': 70},
#         'duration': {'text': '1 min', 'value': 61},
#         'end_location': {'lat': 50.0983823, 'lng': 14.4270437},
#         'html_instructions': 'Turn <b>right</b> onto <b>Letohradská</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'uzwpHu}`wAXtD'},
#         'start_location': {'lat': 50.0985148, 'lng': 14.427954},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': '{}upHwc`wA[mAIOGHk@`@WkA]aBYsAGe@?q@C]NGQqAs@}DIIAo@Ak@AU[DeANAK_Df@aG`AqALqAV}Fx@oBZYDw@wHi@iHSwBWu@o@eDOk@]w@i@yAa@i@][wBaBwD@m@@u@fGgB`TICB@CV]`ErAg@tDmABTXtD'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
# Out:
# '14 mins'

# %%
gmaps.directions(placeids[0], placeids[1],mode='transit',departure_time=now)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-117-56892c0ffe12> in <module>
# ----> 1 gmaps.directions(placeids[0], placeids[1],mode='transit',departure_time=now)
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/directions.py in directions(client, origin, destination, mode, waypoints, alternatives, avoid, language, units, region, departure_time, arrival_time, optimize_waypoints, transit_mode, transit_routing_preference, traffic_model)
#     149         params["traffic_model"] = traffic_model
#     150
# --> 151     return client._request("/maps/api/directions/json", params).get("routes", [])
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258                 result = extract_body(response)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#     262             return result
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275     def _get_body(self, response):
#     276         if response.status_code != 200:
# --> 277             raise googlemaps.exceptions.HTTPError(response.status_code)
#     278
#     279         body = response.json()
#
# HTTPError: HTTP Error: 400

# %%
gmaps.distance_matrix(placeids[0], placeids[1])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-128-dfd1aaef765b> in <module>
# ----> 1 gmaps.distance_matrix(placeids[0], placeids[1])
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/distance_matrix.py in distance_matrix(client, origins, destinations, mode, language, avoid, units, departure_time, arrival_time, transit_mode, transit_routing_preference, traffic_model, region)
#     136         params["region"] = region
#     137
# --> 138     return client._request("/maps/api/distancematrix/json", params)
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     258                 result = extract_body(response)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#     262             return result
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     275     def _get_body(self, response):
#     276         if response.status_code != 200:
# --> 277             raise googlemaps.exceptions.HTTPError(response.status_code)
#     278
#     279         body = response.json()
#
# HTTPError: HTTP Error: 400

# %%
f"point:{pois[0]['geoCode']['latitude']},{pois[0]['geoCode']['longitude']}"
# Out:
# 'point:50.085133,14.424776'

# %%
candidates = gmaps.find_place(input = pois[0]['name'], input_type='textquery',fields=['place_id'],location_bias=f"point:{pois[0]['geoCode']['latitude']},{pois[0]['geoCode']['longitude']}")
placeid = candidates['candidates'][0]['place_id']

# %%
placeid
# Out:
# 'ChIJlxSKQqOUC0cROf8ruWvkSOg'

# %%
placeid
# Out:
# 'ChIJqSCReOuUC0cREEclXxCXQVM'

# %%
gmaps.geocode('')

# %%
deets = gmaps.place(geocode_result[0]['place_id'])

# %%
deets = gmaps.place(geocode_result[0]['place_id'])

# %%
deets['result']['geometry']['location']
# Out:
# {'lat': 51.52725940000001, 'lng': -0.08702050000000001}

# %%
deets['result']['photos']
# Out:
# [{'height': 426,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAAtalm9OZgfCq58PEbGlMHji3yfWr6JIj1Q4XwFELDksszDqADz6k_YVvGL65oCwHXqxSf8ncdjhD_h57BvCzWvSS2a6gSyQ_UEabuDAqpAZRE50YPhEeAALRrljrQ6QZ3EhAEkKot3M3hrQO6uJzKM3W2GhTvlKDwPK2gPGz-QFWb5_XUou32Rw',
#   'width': 758},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAA74t1xX68coAzdO8h-nQuQHQuI5mo9g6FVJpITZMwAxALRRyOZXTYNEeAL5K3oTsV7q77V1Ia28GsqAWeBe4E-tzWPN-gH5DLNE33eIhrMZWQsbjWLYR6sjtZ8lWi0qvbEhD2b3z6SBFQSuqJyK2OJGalGhRuKKc9vseUCnsJ_00HJ6oKpJYYFA',
#   'width': 3960},
#  {'height': 3024,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109014961715875174436/photos">Amar Patel</a>'],
#   'photo_reference': 'CmRaAAAAcWi2XFaF05stQ94oL8ssZY-HdcrZYphbXx7__N0VQ3s-om66G0_ML9PdW3zAn_JiAq8C7s8SU6OpvfvPJ6miWQtrAZTMnMiSdlgIVKbE0Jr7svFHsv0tMcIqU0XmrO7TEhA7uUSjfYrrUXr4QhAXC3I0GhS22-MUDGei3LK7sf-zFjAiZThFOA',
#   'width': 4032},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAArVgYieXzh0qnelNAuKBOnBBvGZHJATAYKLTtFlYQXTNEtJ6VJR3TauzijJPprNHN8ZxSoIw0qHk9Arp8GxtUEtG6fCo4gAv0U5Fm_iCEp8QwmHCdz2hPHemtgn9aJpqEEhDdM08kKDDJsGNK3UA7YkBCGhSGQnfvQCH8Hw4r4XYjkggS7OGGwQ',
#   'width': 3960},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAAzrCPn2mexo-TLKF4uS3qnTZZ_kITYJGbk4UtiNWxSzduqqR1kvAAi1AgEd1Hej5E3z-Ash82qh5jNuhyVaEy05bfFallFazEo1aDq2GTVJYBcX_LAi0lItelcjdoHROcEhAfvjzD-GtnbblZEWmJncCmGhTr0AInXIS7VO5MtrCyaa7z8H81SQ',
#   'width': 3960},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAA8nmsSEqEfX6QZHwIIJy-uEODiG5nyM8T8MQuGuj7bmUdNpZNlyhlTY6Qt4ssbMq85RCHxn_XnGBLTXa3XyyqynkpC_NOYU7BjDF6qixR4Tp5014AKf6LypWQOtLX4-xyEhBaEW-pPGrAfvMw4LsgpI2tGhQiSf2q6qi9vY-gnznJzWlh60zfjA',
#   'width': 3960},
#  {'height': 2610,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101934449753347407176/photos">Anna Newman</a>'],
#   'photo_reference': 'CmRaAAAAHvCFnYbgzy3dPL-H4FCPxYGTDRYT6rtYDXibkZDbhk_cv8PxeBjU-j3sOatYxTgw-PlWK2BxEWqbpA0_jeUvn3rWqn_7NdSTXtpWl9ll8TGP_fAnFiybVAw3vDWAGwXuEhCrkADZsA8L-KClTv83q8wfGhSfN4JFod6y1egyGyax6UL-Li2k1Q',
#   'width': 4640},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAA96X8P2JR7STMJAsWjrLtacRLZturS9-dDm6FypcQFlIVKrx3_6qbOjrN_4MTIUK7FSBXnR8E5TCPI9tcWNfMAnJBOoxl3Jdu8EWfydcevgb9ucocZQvAkCV7ecPMRE_9EhBycH19fEPd79z5Vc6CdhzlGhRQ_Nox3DpybhpzxlAVvWBPfCgnzw',
#   'width': 3960},
#  {'height': 2640,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAAoqcnvUutbRq6hecJsVfxtsRzl4SPFjKtCrh5HuKmX_MtPz7NpfQ3njdby_t5hlalH6gGr5mW7aXojXhIz8YTHJ4rpRC_RXUMLMNRKbQIn0_xdIyqGG7xpeBBylGocxr8EhC2kKDgsFNE0CTuYroBkzWUGhSxPd5HMp_NjCxMh-70Ul6gWauuAg',
#   'width': 3960},
#  {'height': 1266,
#   'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>'],
#   'photo_reference': 'CmRaAAAA3SpVJocYhDOhaJ_rKnh5a-gHCwrkN376uqZm3rm7TY9DUn4THQhArwUcA6RS9tSGx4_HVPD7m_JZ7qLbTqualNc8eeYZNzTyJ0dOM-Gy5Nio9vVllJ-uljj-oBKqmfiYEhBCaz7U3Ta20QAxVN0ljZKMGhTel_iiFAVnlPtGTLX_jdCdIrpEBQ',
#   'width': 1900}]

# %%
deets['result']['photos'][0]['html_attributions']
# Out:
# ['<a href="https://maps.google.com/maps/contrib/102939174042935545234/photos">WeWork 41 Corsham St</a>']

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://maps.google.com/maps/contrib/102939174042935545234/photos")
# Out:
# <img src="https://maps.google.com/maps/contrib/102939174042935545234/photos"/>

# %%
pois[0]['geoCode']
# Out:
# {'latitude': 50.085133, 'longitude': 14.424776}

# %%
gmaps.directions(pois[0]['geoCode'],pois[1]['geoCode'],mode='transit')
# Out:
# [{'bounds': {'northeast': {'lat': 50.09358, 'lng': 14.4553678},
#    'southwest': {'lat': 50.08361, 'lng': 14.42388}},
#   'copyrights': 'Map data ©2019 Google',
#   'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#   'legs': [{'arrival_time': {'text': '8:19pm',
#      'time_zone': 'Europe/Prague',
#      'value': 1564337997},
#     'departure_time': {'text': '8:06pm',
#      'time_zone': 'Europe/Prague',
#      'value': 1564337199},
#     'distance': {'text': '3.0 km', 'value': 3040},
#     'duration': {'text': '13 mins', 'value': 798},
#     'end_address': 'Křižíkova 386/105, 186 00 Karlín, Czechia',
#     'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#     'start_address': 'Swarovski Boutique, Na Příkopě 15, 110 00 Praha-Staré Město, Czechia',
#     'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#     'steps': [{'distance': {'text': '0.2 km', 'value': 183},
#       'duration': {'text': '3 mins', 'value': 161},
#       'end_location': {'lat': 50.08361, 'lng': 14.42398},
#       'html_instructions': 'Walk to Můstek',
#       'polyline': {'points': 'yfupHej`wADHhAlBT\\NVJSdDN'},
#       'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#       'steps': [{'distance': {'text': '91 m', 'value': 91},
#         'duration': {'text': '1 min', 'value': 68},
#         'end_location': {'lat': 50.08450260000001, 'lng': 14.4239639},
#         'html_instructions': 'Head <b>southwest</b> on <b>Na Příkopě</b> toward <b>Havířská</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'yfupHej`wADHhAlBT\\NV'},
#         'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '92 m', 'value': 92},
#         'duration': {'text': '2 mins', 'value': 93},
#         'end_location': {'lat': 50.08361, 'lng': 14.42398},
#         'html_instructions': 'Take entrance <span class="location">Můstek \'A\', ul. Na Příkopě</span>',
#         'polyline': {'points': 'wbupHke`wAdDN'},
#         'start_location': {'lat': 50.08444, 'lng': 14.42406},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.4 km', 'value': 2378},
#       'duration': {'text': '4 mins', 'value': 255},
#       'end_location': {'lat': 50.09263, 'lng': 14.45204},
#       'html_instructions': 'Subway towards Černý Most',
#       'polyline': {'points': 'q}tpH{d`wAIRkCeDiEkE{DmEuGiH{AmC}AaEoAeG?C{BkHwAmFaAiIOgGF_HC}CUgHi@cI_@kFo@mKy@iHqAoJ}A_Ly@mFDC'},
#       'start_location': {'lat': 50.08361, 'lng': 14.42398},
#       'transit_details': {'arrival_stop': {'location': {'lat': 50.09263,
#          'lng': 14.45204},
#         'name': 'Křižíkova'},
#        'arrival_time': {'text': '8:13pm',
#         'time_zone': 'Europe/Prague',
#         'value': 1564337615},
#        'departure_stop': {'location': {'lat': 50.08361, 'lng': 14.42398},
#         'name': 'Můstek'},
#        'departure_time': {'text': '8:09pm',
#         'time_zone': 'Europe/Prague',
#         'value': 1564337360},
#        'headsign': 'Černý Most',
#        'line': {'agencies': [{'name': 'Pražská integrovaná doprava',
#           'phone': '011 420 234 704 560',
#           'url': 'https://pid.cz/'}],
#         'color': '#f2c10a',
#         'name': 'Zličín - Černý Most',
#         'short_name': 'B',
#         'url': 'https://pid.cz/linka/B',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#          'name': 'Subway',
#          'type': 'SUBWAY'}},
#        'num_stops': 3},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.5 km', 'value': 479},
#       'duration': {'text': '6 mins', 'value': 381},
#       'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#       'html_instructions': 'Walk to Křižíkova 386/105, 186 00 Karlín, Czechia',
#       'polyline': {'points': '}uvpHgtewA}DtA@Dp@YNIBEBGBO`@S\\QTGaB}Lk@gESH'},
#       'start_location': {'lat': 50.09263, 'lng': 14.45204},
#       'steps': [{'distance': {'text': '0.1 km', 'value': 109},
#         'duration': {'text': '2 mins', 'value': 110},
#         'end_location': {'lat': 50.09358, 'lng': 14.45161},
#         'html_instructions': 'Take exit <span class="location">Sokolovská ul., TRAM Palmovka</span>',
#         'polyline': {'points': '}uvpHgtewA}DtA'},
#         'start_location': {'lat': 50.09263, 'lng': 14.45204},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 107},
#         'duration': {'text': '1 min', 'value': 79},
#         'end_location': {'lat': 50.0927532, 'lng': 14.4521385},
#         'html_instructions': 'Head <b>south</b> on <b>Thámova</b> toward <b>Křižíkova</b>',
#         'polyline': {'points': 'y{vpHkqewAp@YNIBEBGBO`@S\\QTG'},
#         'start_location': {'lat': 50.0935747, 'lng': 14.4515848},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 248},
#         'duration': {'text': '3 mins', 'value': 182},
#         'end_location': {'lat': 50.0934648, 'lng': 14.4553678},
#         'html_instructions': 'Turn <b>left</b> onto <b>Křižíkova</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uvvpH{tewAaB}Lk@gE'},
#         'start_location': {'lat': 50.0927532, 'lng': 14.4521385},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 10},
#         'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#         'html_instructions': 'Turn <b>left</b> onto <b>Šaldova</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c{vpHaifwASH'},
#         'start_location': {'lat': 50.0934648, 'lng': 14.4553678},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'yfupHej`wAtBlDJSdDNIRkCeDiEkE{DmEuGiH{AmC}AaEoAeG?C{BkHwAmFaAiIOgGF_HC}CUgHi@cIoAyRy@iHqAoJwCmSDC}DtA@Dp@YROFW~@e@TGaB}Lk@gESH'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
origins = [pois[i]['geoCode'] for i in range(len(pois))]
destinations = [pois[i]['geoCode'] for i in range(len(pois))]

gmaps.directions(origins[0],origins[1],mode='transit')
# Out:
# [{'bounds': {'northeast': {'lat': 50.09358, 'lng': 14.4553678},
#    'southwest': {'lat': 50.08361, 'lng': 14.42388}},
#   'copyrights': 'Map data ©2019 Google',
#   'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#   'legs': [{'arrival_time': {'text': '8:34pm',
#      'time_zone': 'Europe/Prague',
#      'value': 1564338897},
#     'departure_time': {'text': '8:21pm',
#      'time_zone': 'Europe/Prague',
#      'value': 1564338099},
#     'distance': {'text': '3.0 km', 'value': 3040},
#     'duration': {'text': '13 mins', 'value': 798},
#     'end_address': 'Křižíkova 386/105, 186 00 Karlín, Czechia',
#     'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#     'start_address': 'Swarovski Boutique, Na Příkopě 15, 110 00 Praha-Staré Město, Czechia',
#     'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#     'steps': [{'distance': {'text': '0.2 km', 'value': 183},
#       'duration': {'text': '3 mins', 'value': 161},
#       'end_location': {'lat': 50.08361, 'lng': 14.42398},
#       'html_instructions': 'Walk to Můstek',
#       'polyline': {'points': 'yfupHej`wADHhAlBT\\NVJSdDN'},
#       'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#       'steps': [{'distance': {'text': '91 m', 'value': 91},
#         'duration': {'text': '1 min', 'value': 68},
#         'end_location': {'lat': 50.08450260000001, 'lng': 14.4239639},
#         'html_instructions': 'Head <b>southwest</b> on <b>Na Příkopě</b> toward <b>Havířská</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'yfupHej`wADHhAlBT\\NV'},
#         'start_location': {'lat': 50.0850945, 'lng': 14.4248348},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '92 m', 'value': 92},
#         'duration': {'text': '2 mins', 'value': 93},
#         'end_location': {'lat': 50.08361, 'lng': 14.42398},
#         'html_instructions': 'Take entrance <span class="location">Můstek \'A\', ul. Na Příkopě</span>',
#         'polyline': {'points': 'wbupHke`wAdDN'},
#         'start_location': {'lat': 50.08444, 'lng': 14.42406},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.4 km', 'value': 2378},
#       'duration': {'text': '4 mins', 'value': 255},
#       'end_location': {'lat': 50.09263, 'lng': 14.45204},
#       'html_instructions': 'Subway towards Černý Most',
#       'polyline': {'points': 'q}tpH{d`wAIRkCeDiEkE{DmEuGiH{AmC}AaEoAeG?C{BkHwAmFaAiIOgGF_HC}CUgHi@cI_@kFo@mKy@iHqAoJ}A_Ly@mFDC'},
#       'start_location': {'lat': 50.08361, 'lng': 14.42398},
#       'transit_details': {'arrival_stop': {'location': {'lat': 50.09263,
#          'lng': 14.45204},
#         'name': 'Křižíkova'},
#        'arrival_time': {'text': '8:28pm',
#         'time_zone': 'Europe/Prague',
#         'value': 1564338515},
#        'departure_stop': {'location': {'lat': 50.08361, 'lng': 14.42398},
#         'name': 'Můstek'},
#        'departure_time': {'text': '8:24pm',
#         'time_zone': 'Europe/Prague',
#         'value': 1564338260},
#        'headsign': 'Černý Most',
#        'line': {'agencies': [{'name': 'Pražská integrovaná doprava',
#           'phone': '011 420 234 704 560',
#           'url': 'https://pid.cz/'}],
#         'color': '#f2c10a',
#         'name': 'Zličín - Černý Most',
#         'short_name': 'B',
#         'url': 'https://pid.cz/linka/B',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png',
#          'name': 'Subway',
#          'type': 'SUBWAY'}},
#        'num_stops': 3},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.5 km', 'value': 479},
#       'duration': {'text': '6 mins', 'value': 381},
#       'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#       'html_instructions': 'Walk to Křižíkova 386/105, 186 00 Karlín, Czechia',
#       'polyline': {'points': '}uvpHgtewA}DtA@Dp@YNIBEBGBO`@S\\QTGaB}Lk@gESH'},
#       'start_location': {'lat': 50.09263, 'lng': 14.45204},
#       'steps': [{'distance': {'text': '0.1 km', 'value': 109},
#         'duration': {'text': '2 mins', 'value': 110},
#         'end_location': {'lat': 50.09358, 'lng': 14.45161},
#         'html_instructions': 'Take exit <span class="location">Sokolovská ul., TRAM Palmovka</span>',
#         'polyline': {'points': '}uvpHgtewA}DtA'},
#         'start_location': {'lat': 50.09263, 'lng': 14.45204},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 107},
#         'duration': {'text': '1 min', 'value': 79},
#         'end_location': {'lat': 50.0927532, 'lng': 14.4521385},
#         'html_instructions': 'Head <b>south</b> on <b>Thámova</b> toward <b>Křižíkova</b>',
#         'polyline': {'points': 'y{vpHkqewAp@YNIBEBGBO`@S\\QTG'},
#         'start_location': {'lat': 50.0935747, 'lng': 14.4515848},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 248},
#         'duration': {'text': '3 mins', 'value': 182},
#         'end_location': {'lat': 50.0934648, 'lng': 14.4553678},
#         'html_instructions': 'Turn <b>left</b> onto <b>Křižíkova</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uvvpH{tewAaB}Lk@gE'},
#         'start_location': {'lat': 50.0927532, 'lng': 14.4521385},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 10},
#         'end_location': {'lat': 50.0935618, 'lng': 14.4553186},
#         'html_instructions': 'Turn <b>left</b> onto <b>Šaldova</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c{vpHaifwASH'},
#         'start_location': {'lat': 50.0934648, 'lng': 14.4553678},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'yfupHej`wAtBlDJSdDNIRkCeDiEkE{DmEuGiH{AmC}AaEoAeG?C{BkHwAmFaAiIOgGF_HC}CUgHi@cIoAyRy@iHqAoJwCmSDC}DtA@Dp@YROFW~@e@TGaB}Lk@gESH'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
dist_matrix = gmaps.distance_matrix(origins,destinations,mode='transit')

# %%
pd.DataFrame.from_dict(origins).mean()
# Out:
# latitude     50.087013
# longitude    14.430674
# dtype: float64

# %%
origins
# Out:
# [{'latitude': 50.085133, 'longitude': 14.424776},
#  {'latitude': 50.09354, 'longitude': 14.455214},
#  {'latitude': 50.08562, 'longitude': 14.431791},
#  {'latitude': 50.08641, 'longitude': 14.420797},
#  {'latitude': 50.09586, 'longitude': 14.427088},
#  {'latitude': 50.08884, 'longitude': 14.419975},
#  {'latitude': 50.086445, 'longitude': 14.42011},
#  {'latitude': 50.083973, 'longitude': 14.414278},
#  {'latitude': 50.081203, 'longitude': 14.444147},
#  {'latitude': 50.08311, 'longitude': 14.44856}]

# %%
ll = [[dist_matrix['rows'][o]['elements'][d]['duration']['value'] for d in range(len(destinations))] for o in range(len(origins))]

# %%
ll
# Out:
# [[0, 798, 478, 300, 1094, 416, 326, 683, 1152, 1138],
#  [867, 0, 840, 1019, 1349, 1244, 1086, 1276, 1832, 1511],
#  [472, 776, 0, 704, 958, 839, 771, 736, 902, 781],
#  [313, 970, 672, 0, 955, 210, 65, 538, 1424, 1303],
#  [1001, 1132, 813, 995, 0, 773, 976, 773, 1438, 1317],
#  [444, 1404, 869, 224, 914, 0, 224, 567, 1378, 1554],
#  [346, 1043, 745, 70, 961, 215, 0, 499, 1391, 1438],
#  [714, 1358, 767, 565, 1140, 658, 512, 0, 1519, 1398],
#  [972, 1377, 743, 1129, 1552, 1175, 1196, 1329, 0, 361],
#  [891, 1381, 575, 1129, 1315, 1279, 1285, 1161, 367, 0]]

# %%
dist_matrix['rows'][0]['elements'][1]
# Out:
# {'distance': {'text': '3.0 km', 'value': 3040},
#  'duration': {'text': '13 mins', 'value': 798},
#  'fare': {'currency': 'CZK', 'text': 'CZK\xa024.00', 'value': 24},
#  'status': 'OK'}

# %%
#algo to find best path through some weights
#assume there is a visited list, where you dont want to go to 
#assume you start at the origin, the next node is simply the next nearest node. 

path = [0]
visited = set([0])
current_location = 0

# %%
visited
# Out:
# {0}

# %%
ll[current_location]
# Out:
# [0, 798, 478, 300, 1094, 416, 326, 683, 1152, 1138]

# %%
min(ll[current_location])
# Out:
# 0

# %%
import numpy as np
lla = np.array(ll)

# %%
lla
# Out:
# array([[   0,  798,  478,  300, 1094,  416,  326,  683, 1152, 1138],
#        [ 867,    0,  840, 1019, 1349, 1244, 1086, 1276, 1832, 1511],
#        [ 472,  776,    0,  704,  958,  839,  771,  736,  902,  781],
#        [ 313,  970,  672,    0,  955,  210,   65,  538, 1424, 1303],
#        [1001, 1132,  813,  995,    0,  773,  976,  773, 1438, 1317],
#        [ 444, 1404,  869,  224,  914,    0,  224,  567, 1378, 1554],
#        [ 346, 1043,  745,   70,  961,  215,    0,  499, 1391, 1438],
#        [ 714, 1358,  767,  565, 1140,  658,  512,    0, 1519, 1398],
#        [ 972, 1377,  743, 1129, 1552, 1175, 1196, 1329,    0,  361],
#        [ 891, 1381,  575, 1129, 1315, 1279, 1285, 1161,  367,    0]])

# %%
np.factorial(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-0f356967b2b6> in <module>
# ----> 1 np.factorial(10)
#
# AttributeError: module 'numpy' has no attribute 'factorial'

# %%
import tsp

# %%
r = range(len(ll))

# %%
r
# Out:
# range(0, 10)

# %%
ll
# Out:
# [[0, 798, 478, 300, 1094, 416, 326, 683, 1152, 1138],
#  [867, 0, 840, 1019, 1349, 1244, 1086, 1276, 1832, 1511],
#  [472, 776, 0, 704, 958, 839, 771, 736, 902, 781],
#  [313, 970, 672, 0, 955, 210, 65, 538, 1424, 1303],
#  [1001, 1132, 813, 995, 0, 773, 976, 773, 1438, 1317],
#  [444, 1404, 869, 224, 914, 0, 224, 567, 1378, 1554],
#  [346, 1043, 745, 70, 961, 215, 0, 499, 1391, 1438],
#  [714, 1358, 767, 565, 1140, 658, 512, 0, 1519, 1398],
#  [972, 1377, 743, 1129, 1552, 1175, 1196, 1329, 0, 361],
#  [891, 1381, 575, 1129, 1315, 1279, 1285, 1161, 367, 0]]

# %%
ll[2][3]
# Out:
# 704

# %%
dist = {(i,j): ll[i][j] for i in r for j in r}

# %%
print(tsp.tsp(r, dist))
# Out:
# (6222.0, [0, 8, 9, 2, 1, 4, 7, 6, 3, 5])

# %%
path = [0, 8, 9, 2, 1, 4, 7, 6, 3, 5]

# %%
[loc-1 for loc in path[1:]]
# Out:
# [7, 8, 1, 0, 3, 6, 5, 2, 4]
